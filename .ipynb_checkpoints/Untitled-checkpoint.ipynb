# %%
df = pd.read_csv('games_form.csv')

# %%
import pandas as pd

# %%
df.dropna(axis=0)
# Out:
#          Timestamp  עמישם התצפיתן                שם קבוצה מארחת תאריך המשחק  \
# 0   07-09-17 12:36     ספיר מסיקה                ביתר מול אשדוד    28-08-17
# 1   07-09-17 18:06   סתיו שר שלום     בית"ר ירושלים- מ.ס. אשדוד    28-08-17
# 2   09-09-17 19:55            ספי       מכבי תל אביב -בני סכנין    09-09-17
# 3    10-09-17 8:06     ספיר מסיקה          אשדוד מול קרית שמונה    09-09-17
# 4   13-09-17 11:40   סתיו שר שלום  מכבי פתח תקווה- ביתר ירושלים    11-09-17
# 5   17-09-17 17:50   סתיו שר שלום                 בית"ר ירושלים    16-09-17
# 6   03-10-17 17:40   סתיו שר שלום                 בית"ר ירושלים    25-09-17
# 7   14-10-17 19:52  ספיר ברנשטיין                מכבי פתח תקווה    14-10-17
# 8   22-10-17 14:39   סתיו שר שלום                  ביתר ירושלים    16-10-17
# 9   29-10-17 14:42   סתיו שר שלום                 בית"ר ירושלים    28-10-17
# 10  30-10-17 22:52  ספיר ברנשטיין                      מכבי פ"ת    30-10-17
# ...
