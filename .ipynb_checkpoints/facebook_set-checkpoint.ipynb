# %%
import pandas as pd

# %%
df=pd.read_excel('facebook_set/הפועל חיפה- פייסבוק.xlsx')

# %%
df.head()
# Out:
#   מועד המשחק           מארחת          אורחת       שעה  \
# 0    19.8.17      הפועל חיפה   הפועל אשקלון  19:15:00
# 1    26.8.17  מכבי פתח תקווה     הפועל חיפה  20:30:00
# 2     9.9.17      הפועל חיפה      בני יהודה  19:15:00
# 3    16.9.17    ביתר ירושלים     הפועל חיפה  20:30:00
# 4    23.9.17      הפועל חיפה  הפועל באר שבע  20:30:00
#
#    כמות ביטויי רגשות שליליים. 3 שעות לפני המשחק  \
# 0                                             1
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    כמות ביטויי רגשות שליליים. 0-24 שעות לפני המשחק  \
# 0                                                1
# 1                                                0
# 2                                                1
# 3                                                0
# 4                                                1
#
# ...

# %%
df.describe()
# Out:
#        כמות ביטויי רגשות שליליים. 3 שעות לפני המשחק  \
# count                                     36.000000
# mean                                       0.527778
# std                                        0.774084
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                        3.000000
#
#        כמות ביטויי רגשות שליליים. 0-24 שעות לפני המשחק  \
# count                                        36.000000
# mean                                          0.833333
# std                                           1.992844
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           1.000000
# ...

# %%
df.isnull().sum()
# Out:
# מועד המשחק                                                     0
# מארחת                                                          0
# אורחת                                                          0
# שעה                                                            0
# כמות ביטויי רגשות שליליים. 3 שעות לפני המשחק                   0
# כמות ביטויי רגשות שליליים. 0-24 שעות לפני המשחק                0
# כמות ביטויי רגשות שליליים. 24-48 שעות לפני המשחק               0
# כמות ביטויי רגשות שליליים. 48-72 שעות לפני המשחק               0
# כמות ביטויי רגשות שליליים. 72-96 שעות לפני המשחק               0
# כמות ביטויי רגשות שליליים. 96-130 שעות לפני המשחק              0
# כמות ביטויי רגשות שליליים. 130-154 שעות לפני המשחק             0
# כמות ביטויי רגשות שליליים. 154-178 שעות לפני המשחק             0
# כמות לייקים לרגשות שליליים. 3 שעות לפני המשחק                  0
# כמות לייקים לרגשות שליליים. 0-24 שעות לפני המשחק               0
# ...

# %%
df[['אורחת','כמות ביטויי רגשות שליליים. 3 שעות לפני המשחק','מארחת']].groupby(['מארחת'], as_index=False).sum().head(20)
# Out:
#             מארחת               אורחת  \
# 0    ביתר ירושלים          הפועל חיפה
# 1       בני יהודה          הפועל חיפה
# 2       בני סכנין          הפועל חיפה
# 3    הפועל אשקלון          הפועל חיפה
# 4   הפועל באר שבע          הפועל חיפה
# 5      הפועל חיפה       בית"ר ירושלים
# 6      הפועל חיפה           בני יהודה
# 7      הפועל חיפה           בני סכנין
# 8      הפועל חיפה        הפועל אשקלון
# 9      הפועל חיפה       הפועל באר שבע
# 10     הפועל חיפה           הפועל עכו
# 11     הפועל חיפה         הפועל רעננה
# 12     הפועל חיפה          מ.ס. אשדוד
# 13     הפועל חיפה          מכבי חיפה
# 14     הפועל חיפה          מכבי נתניה
# 15     הפועל חיפה      מכבי פתח תקווה
# 16     הפועל חיפה        מכבי תל אביב
# 17     הפועל חיפה  עירוני קריית שמונה
# 18      הפועל עכו          הפועל חיפה
# 19    הפועל רעננה          הפועל חיפה
#
#     כמות ביטויי רגשות שליליים. 3 שעות לפני המשחק
# 0                                              0
# 1                                              1
# ...
